# %%
import numpy as np
photo=np.ones([20,512,512,3])
import os
rootDir='.'
for dirName, subdirect, fileList in os.walk(rootDir):
    print('Found Directory:  %s'% dirName)
    
    for fname in fileList:
        print('\t%s'% fname)
        print('Found directory: %s'% dirName)
        
from PIL import Image

for i in photo:
    im=i.resize((512,512,3))
    print(im)
# Out:
# Found Directory:  .
# 	1.jpg
# Found directory: .
# 	10.jpg
# Found directory: .
# 	11.jpg
# Found directory: .
# 	12.jpg
# Found directory: .
# 	13.jpg
# Found directory: .
# 	14.jpg
# Found directory: .
# 	15.jpg
# Found directory: .
# 	16.jpg
# Found directory: .
# 	17.jpg
# Found directory: .
# 	18.jpg
# Found directory: .
# 	19.jpg
# Found directory: .
# 	2.jpg
# Found directory: .
# 	20.jpg
# Found directory: .
# 	3.jpg
# Found directory: .
# 	4.jpg
# Found directory: .
# 	5.jpg
# Found directory: .
# 	6.jpg
# Found directory: .
# 	7.jpg
# Found directory: .
# 	8.jpg
# Found directory: .
# 	9.jpg
# Found directory: .
# 	Untitled.ipynb
# Found directory: .
# Found Directory:  .\.ipynb_checkpoints
# 	Untitled-checkpoint.ipynb
# Found directory: .\.ipynb_checkpoints
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
